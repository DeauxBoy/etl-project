# %%
#import modules
import pandas as pd

# %%
#load in fast food csv
ff_csv = "resources/fast_food.csv"
ff_df_bad_column = pd.read_csv(ff_csv)

# %%
#load in obesity csv
obesity_csv = "resources/obesity.csv"
obesity_df_bad_column = pd.read_csv(obesity_csv)

# %%
#remove the "unnamed" column - ff
ff_df = ff_df_bad_column.drop(columns=["Unnamed: 0", "websites"])

# %%
#renamed post code column - ff
organised_df = ff_df.rename(columns={"name": "Name", "categories": "Categories", "address": "Address", "postalCode":"Post Code", "city": "City", "province": "State (Abbrev)", "country": "Country", "longitude": "Longitude", "latitude": "Latitude"})

# %%
#reorder the columns - ff
ff_reorganised_df = organised_df[["Name", "Categories", "Address", "Post Code", "City", "State (Abbrev)", "Country", "Longitude", "Latitude"]]

# %%
# dropped unused columns and renamed useful columns - ob
obesity_df_fixed_column = obesity_df_bad_column[["Data_Value", "LocationDesc", "Sample_Size", "Low_Confidence_Limit", "High_Confidence_Limit"]]
obesity_fixed_name = obesity_df_fixed_column.rename(columns={"Data_Value":"Percentage of Population", "LocationDesc": "State", "Sample_Size": "Sample Size", "Low_Confidence_Limit": "Low Confidence Limit", "High_Confidence_Limit": "High Confidence Limit"})

# %%
# removed ghost rows - ob
obesity_dropped_df = obesity_fixed_name.iloc[:-9]
obesity_dropped_df.head()
# Out:
#    Percentage of Population     State Sample Size  Low Confidence Limit  \
# 0                      31.4  National     374,073                  31.1
# 1                      36.1   Alabama       6,521                  34.6
# 2                      30.5    Alaska       2,729                  27.8
# 3                      31.4   Arizona       8,183                  29.7
# 4                      37.4  Arkansas       4,922                  35.5
#
#    High Confidence Limit
# 0                   31.6
# 1                   37.7
# 2                   33.4
# 3                   33.2
# 4                   39.4

# %%
#create new column for ob_df
state_abrev = ["USA", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "DC", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "GU", "PR"]

# %%
#add list with abbreviations to ob_df
obesity_dropped_df["State (Abbrev)"] = state_abrev
obesity_dropped_df.head()
# Out:
# <ipython-input-108-83a39f218de7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obesity_dropped_df["State (Abbrev)"] = state_abrev
#    Percentage of Population     State Sample Size  Low Confidence Limit  \
# 0                      31.4  National     374,073                  31.1
# 1                      36.1   Alabama       6,521                  34.6
# 2                      30.5    Alaska       2,729                  27.8
# 3                      31.4   Arizona       8,183                  29.7
# 4                      37.4  Arkansas       4,922                  35.5
#
#    High Confidence Limit State (Abbrev)
# 0                   31.6            USA
# 1                   37.7             AL
# ...

# %%
#put State (Abbrev) column between State and Sample Size columns
cleaned_ob_df = obesity_dropped_df[["Percentage of Population", "State", "State (Abbrev)", "Sample Size", "Low Confidence Limit", "High Confidence Limit"]]
cleaned_ob_df.head()
# Out:
#    Percentage of Population     State State (Abbrev) Sample Size  \
# 0                      31.4  National            USA     374,073
# 1                      36.1   Alabama             AL       6,521
# 2                      30.5    Alaska             AK       2,729
# 3                      31.4   Arizona             AZ       8,183
# 4                      37.4  Arkansas             AR       4,922
#
#    Low Confidence Limit  High Confidence Limit
# 0                  31.1                   31.6
# 1                  34.6                   37.7
# 2                  27.8                   33.4
# 3                  29.7                   33.2
# 4                  35.5                   39.4

# %%
ff_reorganised_df.head()
# Out:
#              Name                                    Categories  \
# 0  SONIC Drive In  American Restaurant and Fast Food Restaurant
# 1  SONIC Drive In                         Fast Food Restaurants
# 2       Taco Bell                          Fast Food Restaurant
# 3          Arby's                                     Fast Food
# 4  Steak 'n Shake                          Fast Food Restaurant
#
#                 Address Post Code          City State (Abbrev) Country  \
# 0      800 N Canal Blvd     70301     Thibodaux             LA      US
# 1      800 N Canal Blvd     70301     Thibodaux             LA      US
# 2   206 Wears Valley Rd     37863  Pigeon Forge             TN      US
# 3          3652 Parkway     37863  Pigeon Forge             TN      US
# 4  2118 Mt Zion Parkway     30260        Morrow             GA      US
#
#    Longitude   Latitude
# 0 -90.814742  29.814697
# 1 -90.814742  29.814697
# 2 -83.580553  35.803788
# 3 -83.551408  35.782339
# 4 -84.321143  33.562738

# %%
ff_reorganised_df.to_csv(path_or_buf='Users\ShaunM\Desktop\export_dataframe.csv')

# %%
ff_csv = "resources/fast_food.csv"
ff_df_bad_column = pd.read_csv(ff_csv)
# Out:
# array(['SONIC Drive In', 'Taco Bell', "Arby's", "Steak 'n Shake",
#        "Wendy's", 'Burger King', 'Chipotle Mexican Grill', '7-Eleven',
#        'Dairy Queen', 'Mr. Hero', 'Golden Chick', "Carl's Jr", 'Checkers',
#        "Rally's", "Togo's", 'Little Q Hot Pot', "McDonald's", 'Five Guys',
#        'Boston Road Pizza', 'Boston Market',
#        "D'Angelo Grilled Sandwiches", "Nino's Pizzarama",
#        "Filippi's Pizza Grotto", 'Jack in the Box', 'Round Table Pizza',
#        'El Pollo Loco', 'In-N-Out Burger', 'Copper Oven Artisan Pizza',
#        'Del Taco', 'Little Caesars Pizza', 'Sbarro',
#        "Casey's General Store", 'SUBWAY', "Fat Patty's", 'Pizza Hut',
#        "Culver's", 'KFC', 'SONIC Drive-In', 'Whataburger', 'Chick-Fil-A',
#        'Firehouse Subs', "Cupie's Drive-In", "Primo's Pizza",
#        "Simple Simon's Pizza", 'CASA Mexicana', 'Bob Evans',
#        'Players Grill', 'Back Yard Burgers', "Italo's Pizza",
# ...

# %%
semi_cleaned_ff_csv = "resources/semicleanedff.csv"
semi_cleaned_ff_df = pd.read_csv(semi_cleaned_ff_csv)
cleaned_ff_df = semi_cleaned_ff_df.drop(columns=["Unnamed: 0", "Categories"])
cleaned_ff_df.head()
# Out:
#              Name               Address Post Code          City  \
# 0  SONIC Drive In      800 N Canal Blvd     70301     Thibodaux
# 1  SONIC Drive In      800 N Canal Blvd     70301     Thibodaux
# 2       Taco Bell   206 Wears Valley Rd     37863  Pigeon Forge
# 3          Arby's          3652 Parkway     37863  Pigeon Forge
# 4  Steak 'n Shake  2118 Mt Zion Parkway     30260        Morrow
#
#   State (Abbrev) Country  Longitude   Latitude
# 0             LA      US -90.814742  29.814697
# 1             LA      US -90.814742  29.814697
# 2             TN      US -83.580553  35.803788
# 3             TN      US -83.551408  35.782339
# 4             GA      US -84.321143  33.562738
